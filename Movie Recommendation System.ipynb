# %%
import numpy as np
import pandas as pd

# %%
credits = pd.read_csv("C:\\Users\\kmsre\\OneDrive\\Desktop\\python\\movieRecommendation\\tmdb_5000_credits\\tmdb_5000_credits.csv")

# %%
movies = pd.read_csv("C:\\Users\\kmsre\\OneDrive\\Desktop\\python\\movieRecommendation\\tmdb_5000_movies\\tmdb_5000_movies.csv")

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits_rename = credits.rename(index=str, columns={"movie_id": "id"})

# %%
credits_rename.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies_merge=pd.merge(credits_rename, movies, on=["id"])

# %%
movies_merge.head()
# Out:
#        id                                   title_x  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...  250000000
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies_merge.shape
# Out:
# (4803, 23)

# %%
movies_merge.isna().any()
# Out:
# id                      False
# title_x                 False
# cast                    False
# crew                    False
# budget                  False
# genres                  False
# homepage                 True
# keywords                False
# original_language       False
# original_title          False
# overview                 True
# popularity              False
# production_companies    False
# production_countries    False
# release_date             True
# revenue                 False
# runtime                  True
# spoken_languages        False
# status                  False
# tagline                  True
# title_y                 False
# vote_average            False
# vote_count              False
# dtype: bool

# %%
movies_merge=movies_merge.dropna()

# %%
movies_merge.isna().any()
# Out:
# id                      False
# title_x                 False
# cast                    False
# crew                    False
# budget                  False
# genres                  False
# homepage                False
# keywords                False
# original_language       False
# original_title          False
# overview                False
# popularity              False
# production_companies    False
# production_countries    False
# release_date            False
# revenue                 False
# runtime                 False
# spoken_languages        False
# status                  False
# tagline                 False
# title_y                 False
# vote_average            False
# vote_count              False
# dtype: bool

# %%
movies_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1493 entries, 0 to 4801
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1493 non-null   int64
#  1   title_x               1493 non-null   object
#  2   cast                  1493 non-null   object
#  3   crew                  1493 non-null   object
#  4   budget                1493 non-null   int64
#  5   genres                1493 non-null   object
#  6   homepage              1493 non-null   object
#  7   keywords              1493 non-null   object
#  8   original_language     1493 non-null   object
#  9   original_title        1493 non-null   object
#  10  overview              1493 non-null   object
#  11  popularity            1493 non-null   float64
#  12  production_companies  1493 non-null   object
#  13  production_countries  1493 non-null   object
#  14  release_date          1493 non-null   object
# ...

# %%
v=movies_merge['vote_count']
print(v)
R=movies_merge['vote_average']
print(R)
C=movies_merge['vote_average'].mean()
print(C)
m=movies_merge['vote_count'].quantile(0.70)
print(m)
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4773      755
# 4781        1
# 4791        1
# 4796      658
# 4801        7
# Name: vote_count, Length: 1493, dtype: int64
# 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       6.1
#        ...
# 4773    7.4
# 4781    6.0
# 4791    2.0
# 4796    6.9
# 4801    5.7
# Name: vote_average, Length: 1493, dtype: float64
# 6.272873409243134
# 1373.3999999999999

# %%
movies_merge['weighted_average']=((R*v)+ (C*m))/(v+m)
movies_merge.head()
# Out:
#        id                                   title_x  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...  250000000
# ...

# %%
movie_ranking=movies_merge.sort_values('weighted_average',ascending=False)
movie_ranking[['original_title', 'vote_count', 'vote_average', 'weighted_average', 'popularity']].head(20)
# Out:
#                                          original_title  vote_count  \
# 662                                          Fight Club        9413
# 65                                      The Dark Knight       12002
# 3337                                      The Godfather        5893
# 96                                            Inception       13752
# 95                                         Interstellar       10867
# 1990                            The Empire Strikes Back        5879
# 329       The Lord of the Rings: The Return of the King        8064
# 1818                                   Schindler's List        4329
# 3865                                           Whiplash        4254
# 2912                                          Star Wars        6624
# 2294                                           千と千尋の神隠し        3840
# 262   The Lord of the Rings: The Fellowship of the Ring        8705
# 1553                                              Se7en        5765
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

weight_average=movie_ranking.sort_values('weighted_average',ascending=False)
plt.figure(figsize=(12,6))
axis1=sns.barplot(x=weight_average['weighted_average'].head(10), y=weight_average['original_title'].head(10), data=weight_average)
plt.xlim(4, 10)
plt.title('Best Movies by average votes', weight='bold')
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_movies.png')

# %%
popularity=movie_ranking.sort_values('popularity',ascending=False)
popularity.head()
# Out:
#          id                  title_x  \
# 546  211672                  Minions
# 95   157336             Interstellar
# 788  293660                 Deadpool
# 94   118340  Guardians of the Galaxy
# 127   76341       Mad Max: Fury Road
#
#                                                   cast  \
# 546  [{"cast_id": 22, "character": "Scarlet Overkil...
# 95   [{"cast_id": 9, "character": "Joseph Cooper", ...
# 788  [{"cast_id": 99, "character": "Wade Wilson / D...
# 94   [{"cast_id": 1, "character": "Peter Quill / St...
# 127  [{"cast_id": 2, "character": "Max Rockatansky"...
#
#                                                   crew     budget  \
# 546  [{"credit_id": "5431b2b10e0a2656e20026c7", "de...   74000000
# 95   [{"credit_id": "52fe4bbf9251416c910e4801", "de...  165000000
# 788  [{"credit_id": "56c986b2925141172f0068b6", "de...   58000000
# 94   [{"credit_id": "538ce329c3a3687155003358", "de...  170000000
# 127  [{"credit_id": "577da370c3a36817f8003838", "de...  150000000
#
# ...

# %%
popularity=movie_ranking.sort_values('popularity',ascending=False)
plt.figure(figsize=(12,6))
ax=sns.barplot(x=popularity['popularity'].head(10), y=popularity['original_title'].head(10), data=popularity)

plt.title('Most Popular by Votes', weight='bold')
plt.xlabel('Score of Popularity', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_popular_movies.png')

# %%
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()
movie_scaled_df=scaling.fit_transform(movies_merge[['weighted_average','popularity']])
movie_normalized_df=pd.DataFrame(movie_scaled_df,columns=['weighted_average','popularity'])
movie_normalized_df.head()
# Out:
#    weighted_average  popularity
# 0          0.680488    0.171792
# 1          0.561342    0.158823
# 2          0.404833    0.122611
# 3          0.790355    0.128249
# 4          0.362029    0.050143

# %%
movies_merge[['normalized_weight_average','normalized_popularity']]= movie_normalized_df

# %%
movies_merge.head()
# Out:
#        id                                   title_x  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...  250000000
# ...

# %%
movies_merge['score'] = movies_merge['normalized_weight_average'] * 0.5 + movies_merge['normalized_popularity'] * 0.5
movies_scored_df = movies_merge.sort_values(['score'], ascending=False)
movies_merge[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                  original_title  normalized_weight_average  \
# 0                                        Avatar                   0.680488
# 1      Pirates of the Caribbean: At World's End                   0.561342
# 2                                       Spectre                   0.404833
# 3                         The Dark Knight Rises                   0.790355
# 4                                   John Carter                   0.362029
# 5                                  Spider-Man 3                   0.306056
# 6                                       Tangled                   0.669436
# 7                       Avengers: Age of Ultron                   0.688443
# 8        Harry Potter and the Half-Blood Prince                   0.702429
# 9            Batman v Superman: Dawn of Justice                   0.234719
# 11                            Quantum of Solace                   0.593948
# ...

# %%
scored_df = movies_merge.sort_values('score', ascending=False)

plt.figure(figsize=(16,6))

ax = sns.barplot(x=scored_df['score'].head(10), y=scored_df['original_title'].head(10), data=scored_df, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')

# %%
movies_merge.head(1)['overview']
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Using Abhishek Thakur's arguments for TF-IDF
tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# Filling NaNs with empty string
movies_merge['overview'] = movies_merge['overview'].fillna('')

# %%
tfv_matrix = tfv.fit_transform(movies_merge['overview'])

# %%
tfv_matrix.shape
# Out:
# (1493, 3862)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# Compute the sigmoid kernel
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)

# %%
indices = pd.Series(movies_merge.index, index=movies_merge['original_title']).drop_duplicates()

# %%
indices
# Out:
# original_title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# Clerks                                      4773
# Dry Spell                                   4781
# Tin Can Man                                 4791
# Primer                                      4796
# Shanghai Calling                            4801
# Length: 1493, dtype: int64

# %%
def give_rec(title, sig=sig):
    # Get the index corresponding to original_title
    idx = indices[title]

    # Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))

    # Sort the movies 
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:11]

    # Movie indices
    movie_indices = [i[0] for i in sig_scores]

    # Top 10 most similar movies
    return movies_merge['original_title'].iloc[movie_indices]
